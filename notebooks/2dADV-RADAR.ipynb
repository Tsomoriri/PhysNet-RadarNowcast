# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.animation as animation
import os
import math
import imageio

# %%
mux = 0.1 
muy = 0.05
def u0(x):
    return np.exp(-100*(x-0.2)**2) # gaussian wave
def u_true(x,t):
    return  u0(x - mu * t)

# 2D advection equation 
def u_2d_true(x, y, t):
        return u0(x - mux * t) * u0(y - muy * t)

# %%
# load radar data

movies = np.load('/home/sushen/PhysNet-RadarNowcast/data/radar_movies.npy')
movies.shape # (980, 40, 40, 20) -- here each movie is of length 20

# in our model we will use the first four images as inputs and predict the
# fifth image
x = movies[:, :, :,  :4]
y = movies[:, :, :, 4:5]


# function: animation of a sequence of radar data (shape = nx,ny,ntime)
def animate(x):
  fig, ax = plt.subplots()
  vmax = np.max(x)
  im = ax.imshow(x[:,:,0], vmin=0, vmax=vmax)
  fig.colorbar(im)
  plt.axis('off')
  def anim_(i):
      im.set_data(x[:,:,i])
      ax.set_title(str(i+1) + '/' + str(x.shape[2]))
  anim = animation.FuncAnimation(
      fig, anim_, interval=300, frames=x.shape[2], repeat_delay=1000)
  plt.show()

# i_plt = 340
# i_plt = 123
i_plt = np.int32(np.random.sample() * movies.shape[0])
animate(x[i_plt,:,:,:])
plt.show()

# train validate test split
tvt = np.tile(['train','train','train','validate','test'], y.shape[0])[:y.shape[0]]
x_train = x[np.where(tvt == 'train')]
y_train = y[np.where(tvt == 'train')]
x_validate = x[np.where(tvt == 'validate')]
y_validate = y[np.where(tvt == 'validate')]
x_test = x[np.where(tvt == 'test')]
y_test = y[np.where(tvt == 'test')]

n_test = x_test.shape[0]
i_plt = np.int32(np.random.sample() * n_test)
true = np.append(x_test[i_plt,:,:,:], y_test[i_plt,:,:,:], axis=2)
# plot an input/output pair
i_plt = 20
i_plt = np.int32(np.random.sample() * x_train.shape[0])
for jj in range(4):
  plt.subplot(1,5,jj+1)
  plt.imshow(x_train[i_plt,:,:,jj])
  plt.axis('off')
  plt.title('input')
plt.subplot(1,5,5)
plt.imshow(y_train[i_plt,:,:,0])
plt.title('target output')
plt.axis('off')
plt.show()
# Out:
# /home/sushen/anaconda3/envs/pinn/lib/python3.11/site-packages/matplotlib/animation.py:892: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
# xr = np.linspace(0,1,nx)
# yr = np.linspace(0,1,ny)
# tr = np.linspace(0,nt-1,nt).T
# # print(f'xr: {xr} \n yr: {yr} \n tr: {tr}')
# # print(f'xrshape: {xr.shape} \n yrshape: {yr.shape} \n trshape: {tr.shape}')
# xrmesh , yrmesh, trmesh = np.meshgrid(xr,yr,tr)
# # print(f'xrmesh: {xrmesh} \n yrmesh: {yrmesh} \n trmesh: {trmesh}')
# print(f'xrmeshshape: {xrmesh.shape} \n yrmeshshape: {yrmesh.shape} \n trmeshshape: {trmesh.shape}')

# ur = u_2d_true(xrmesh,yrmesh,trmesh)

# #print(ur[:,:,0].shape)
# # print(ur[0,:,:].shape)
# # print(xrmesh[0,:,:].shape)
# #plot ur
# plt.contourf(xrmesh[:,:,0], yrmesh[:,:,0], ur[:,:,0])
# plt.xlabel('X')
# plt.ylabel('Y')
# plt.title('Data at t=0')
# plt.colorbar()
# plt.show()

# # Stack the 3 2D arrays along a new third dimension, then reshape into a 2D array
# rin_data = np.stack((xrmesh, yrmesh, trmesh), axis=-1).reshape(-1, 3)
# rin_data = torch.tensor(rin_data).float()
# rout_data = torch.tensor(ur).float().reshape(-1,1)

# rout_data2 = rout_data.numpy().reshape(nx,ny,nt)
# plt.contourf(xrmesh[:,:,0], yrmesh[:,:,0], rout_data2[:,:,0])
# plt.xlabel('X')
# plt.ylabel('Y')
# plt.title(' actual Data(torch) at t=0')
# plt.colorbar()
# plt.show()
# print(f'rin_data shape: {rin_data.shape} \n rout_data shape: {rout_data.shape}')

# %%
class FCN_iPINN(nn.Module):
    "Defines a connected network"
    
    def __init__(self, N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS):
        super().__init__()
        activation = nn.Tanh
        self.fcs = nn.Sequential(*[
                        nn.Linear(N_INPUT, N_HIDDEN),
                        activation()])
        self.fch = nn.Sequential(*[
                        nn.Sequential(*[
                            nn.Linear(N_HIDDEN, N_HIDDEN),
                            activation()]) for _ in range(N_LAYERS-1)])
        self.fce = nn.Linear(N_HIDDEN, N_OUTPUT)
        # Initialize velocities as trainable parameters
        self.velocity_x = nn.Parameter(torch.tensor(1.0))
        self.velocity_y = nn.Parameter(torch.tensor(1.0))
        
    def forward(self, x):
        x = self.fcs(x)
        x = self.fch(x)
        x = self.fce(x)
        return x

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# Initialize the PINN model
N_INPUT = 40 * 40 * 4  # Adjust the input size based on the shape of batch_x
N_OUTPUT = 40* 40
N_HIDDEN = 32
N_LAYERS = 3
pinn = FCN_iPINN(N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS)



# Prepare the input and output data
x_train_tensor = torch.tensor(x_train).float()
y_train_tensor = torch.tensor(y_train).float()
x_test_tensor = torch.tensor(x_test).float()
y_test_tensor = torch.tensor(y_test).float()

# Create a TensorDataset
train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
test_dataset = TensorDataset(x_test_tensor, y_test_tensor)

# Create a DataLoader
batch_size = len(train_dataset)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Define the optimizer
optimizer = torch.optim.Adam(pinn.parameters(), lr=0.001)

# Training loop
num_epochs = 10000
mu_lr = 1e-1
for epoch in range(num_epochs):
    for batch_x, batch_y in train_loader:
        batch_x = batch_x.reshape(batch_size, -1)  # Reshape batch_x to match the input size of the model
        batch_y = batch_y.reshape(batch_size, -1)  # Reshape to (batch_size*nx*ny, 1)
        if batch_x.shape[1] != N_INPUT:
            break
        optimizer.zero_grad()
        
        # Compute the "data loss"e
        uh = pinn(batch_x)
        #print(f'batch_x shape: {batch_x.shape} \n batch_y shape: {batch_y.shape}, output shape: {uh.shape}')
        loss1 = torch.mean((uh - batch_y)**2)  # Use mean squared error
        
        # Generate rin_physics based on the shape of batch_x
        nt_physics = 4  # Assuming nt = 4
        nx_physics, ny_physics = batch_x.shape[1] // nt_physics, batch_x.shape[1] // nt_physics
        xr_physics = torch.linspace(0, 1, nx_physics)
        yr_physics = torch.linspace(0, 1, ny_physics)
        tr_physics = torch.linspace(0, nt_physics-1, nt_physics)
        xr_mesh_physics, yr_mesh_physics, tr_mesh_physics = torch.meshgrid(xr_physics, yr_physics, tr_physics)
        rin_physics = torch.stack((xr_mesh_physics, yr_mesh_physics, tr_mesh_physics), dim=-1).reshape(-1, 3)
        
        rin_physics = torch.ones_like(batch_x, requires_grad=True)

        # Compute the "physics loss"
        uhp = pinn(rin_physics)
        grad = torch.autograd.grad(outputs=uhp, inputs=rin_physics,
                                grad_outputs=torch.ones_like(uhp), create_graph=True)[0]
        dudx = grad[:, 0]
        dudy = grad[:, 1]
        dudt = grad[:, 2]
        physics = dudt + pinn.velocity_x * dudx + pinn.velocity_y * dudy  # Advection equation
        loss2 = torch.mean((physics)**2)
        
        # Backpropagate combined loss
        loss = 2*loss1 + loss2  # Add two loss terms together
        dJdvx = torch.autograd.grad(loss, pinn.velocity_x, retain_graph=True, create_graph=True)[0]
        pinn.velocity_x.data = pinn.velocity_x.data - (mu_lr * dJdvx)
        dJdvy = torch.autograd.grad(loss, pinn.velocity_y, retain_graph=True, create_graph=True)[0]
        pinn.velocity_y.data = pinn.velocity_y.data - (mu_lr * dJdvy)
        loss.backward(retain_graph=True)
        optimizer.step()
    
    if (epoch+1) % 100 == 0:
        print(f'Epoch: {epoch+1}/{num_epochs}, Loss: {loss.item()}')
        print("At iteration: ", epoch, "\n", "The current value of Vx is: ", pinn.velocity_x.item())
        print("At iteration: ", epoch, "\n", "The current value of Vy is: ", pinn.velocity_y.item())
        print(f' NN loss: {loss1.item()}, Physics loss: {loss2.item()}')
# Out:
# /home/sushen/anaconda3/envs/pinn/lib/python3.11/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch: 100/10000, Loss: 1837.40625
# At iteration:  99
#  The current value of Vx is:  0.989631712436676
# At iteration:  99
#  The current value of Vy is:  1.0052776336669922
#  NN loss: 918.703125, Physics loss: 0.0
# Epoch: 200/10000, Loss: 1785.7593994140625
# At iteration:  199
#  The current value of Vx is:  0.9896312355995178
# At iteration:  199
#  The current value of Vy is:  1.0052776336669922
#  NN loss: 892.8796997070312, Physics loss: 0.0
# Epoch: 300/10000, Loss: 1766.1876220703125
# At iteration:  299
#  The current value of Vx is:  0.9896312355995178
# At iteration:  299
#  The current value of Vy is:  1.0052776336669922
#  NN loss: 883.0938110351562, Physics loss: 0.0
# Epoch: 400/10000, Loss: 1759.746337890625
# At iteration:  399
#  The current value of Vx is:  0.9896312355995178
# At iteration:  399
#  The current value of Vy is:  1.0052776336669922
#  NN loss: 879.8731689453125, Physics loss: 0.0
# Epoch: 500/10000, Loss: 1757.905029296875
# At iteration:  499
#  The current value of Vx is:  0.9892920255661011
# At iteration:  499
#  The current value of Vy is:  1.0049265623092651
#  NN loss: 878.9525146484375, Physics loss: 0.0
# Epoch: 600/10000, Loss: 1756.659912109375
# At iteration:  599
#  The current value of Vx is:  -17.617788314819336
# At iteration:  599
#  The current value of Vy is:  -4.347419738769531
#  NN loss: 878.3299560546875, Physics loss: 0.0
# Epoch: 700/10000, Loss: 1744.1314697265625
# At iteration:  699
#  The current value of Vx is:  -17.32233428955078
# At iteration:  699
#  The current value of Vy is:  -4.11312198638916
#  NN loss: 872.0657348632812, Physics loss: 0.0
# Epoch: 800/10000, Loss: 1737.004638671875
# At iteration:  799
#  The current value of Vx is:  -17.322153091430664
# At iteration:  799
#  The current value of Vy is:  -4.112995624542236
#  NN loss: 868.5023193359375, Physics loss: 0.0
# Epoch: 900/10000, Loss: 1732.7161865234375
# At iteration:  899
#  The current value of Vx is:  -17.322153091430664
# At iteration:  899
#  The current value of Vy is:  -4.112995624542236
#  NN loss: 866.3580932617188, Physics loss: 0.0
# Epoch: 1000/10000, Loss: 1729.7515869140625
# At iteration:  999
#  The current value of Vx is:  -17.322153091430664
# At iteration:  999
#  The current value of Vy is:  -4.112995624542236
#  NN loss: 864.8757934570312, Physics loss: 0.0
# Epoch: 1100/10000, Loss: 1727.490234375
# At iteration:  1099
#  The current value of Vx is:  -17.322153091430664
# At iteration:  1099
#  The current value of Vy is:  -4.112995624542236
#  NN loss: 863.7451171875, Physics loss: 0.0
# Epoch: 1200/10000, Loss: 1725.9906005859375
# At iteration:  1199
#  The current value of Vx is:  -17.322141647338867
# At iteration:  1199
#  The current value of Vy is:  -4.112987518310547
#  NN loss: 862.9953002929688, Physics loss: 0.0
# Epoch: 1300/10000, Loss: 1723.10107421875
# At iteration:  1299
#  The current value of Vx is:  -17.32181167602539
# At iteration:  1299
#  The current value of Vy is:  -4.113046646118164
#  NN loss: 861.550537109375, Physics loss: 0.0
# Epoch: 1400/10000, Loss: 1772.5244140625
# At iteration:  1399
#  The current value of Vx is:  1919514368.0
# At iteration:  1399
#  The current value of Vy is:  2571715840.0
#  NN loss: 886.26220703125, Physics loss: 0.0
# Epoch: 1500/10000, Loss: 1847.528076171875
# At iteration:  1499
#  The current value of Vx is:  -371267904.0
# At iteration:  1499
#  The current value of Vy is:  844286272.0
#  NN loss: 923.7640380859375, Physics loss: 0.0
# Epoch: 1600/10000, Loss: 1843.840576171875
# At iteration:  1599
#  The current value of Vx is:  -371267904.0
# At iteration:  1599
#  The current value of Vy is:  844286272.0
#  NN loss: 921.9202880859375, Physics loss: 0.0
# Epoch: 1700/10000, Loss: 1842.78515625
# At iteration:  1699
#  The current value of Vx is:  -371267904.0
# At iteration:  1699
#  The current value of Vy is:  844286272.0
#  NN loss: 921.392578125, Physics loss: 0.0
# Epoch: 1800/10000, Loss: 1839.2236328125
# At iteration:  1799
#  The current value of Vx is:  -371267904.0
# At iteration:  1799
#  The current value of Vy is:  844286272.0
#  NN loss: 919.61181640625, Physics loss: 0.0
# Epoch: 1900/10000, Loss: 1835.5960693359375
# At iteration:  1899
#  The current value of Vx is:  -371267904.0
# At iteration:  1899
#  The current value of Vy is:  844286272.0
#  NN loss: 917.7980346679688, Physics loss: 0.0
# Epoch: 2000/10000, Loss: 1832.5975341796875
# At iteration:  1999
#  The current value of Vx is:  -371267904.0
# At iteration:  1999
#  The current value of Vy is:  844286272.0
#  NN loss: 916.2987670898438, Physics loss: 0.0
# Epoch: 2100/10000, Loss: 1829.78759765625
# At iteration:  2099
#  The current value of Vx is:  -371267904.0
# At iteration:  2099
#  The current value of Vy is:  844286272.0
#  NN loss: 914.893798828125, Physics loss: 0.0
# Epoch: 2200/10000, Loss: 1827.11962890625
# At iteration:  2199
#  The current value of Vx is:  -371267904.0
# At iteration:  2199
#  The current value of Vy is:  844286272.0
#  NN loss: 913.559814453125, Physics loss: 0.0
# Epoch: 2300/10000, Loss: 1824.5736083984375
# At iteration:  2299
#  The current value of Vx is:  -371267904.0
# At iteration:  2299
#  The current value of Vy is:  844286272.0
#  NN loss: 912.2868041992188, Physics loss: 0.0
# Epoch: 2400/10000, Loss: 1822.1343994140625
# At iteration:  2399
#  The current value of Vx is:  -371267904.0
# At iteration:  2399
#  The current value of Vy is:  844286272.0
#  NN loss: 911.0671997070312, Physics loss: 0.0
# Epoch: 2500/10000, Loss: 1819.7900390625
# At iteration:  2499
#  The current value of Vx is:  -371267904.0
# At iteration:  2499
#  The current value of Vy is:  844286272.0
#  NN loss: 909.89501953125, Physics loss: 0.0
# Epoch: 2600/10000, Loss: 1817.5311279296875
# At iteration:  2599
#  The current value of Vx is:  -371267904.0
# At iteration:  2599
#  The current value of Vy is:  844286272.0
#  NN loss: 908.7655639648438, Physics loss: 0.0
# Epoch: 2700/10000, Loss: 1815.3502197265625
# At iteration:  2699
#  The current value of Vx is:  -371267904.0
# At iteration:  2699
#  The current value of Vy is:  844286272.0
#  NN loss: 907.6751098632812, Physics loss: 0.0
# Epoch: 2800/10000, Loss: 1813.2408447265625
# At iteration:  2799
#  The current value of Vx is:  -371267904.0
# At iteration:  2799
#  The current value of Vy is:  844286272.0
#  NN loss: 906.6204223632812, Physics loss: 0.0
# Epoch: 2900/10000, Loss: 1811.1976318359375
# At iteration:  2899
#  The current value of Vx is:  -371267904.0
# At iteration:  2899
#  The current value of Vy is:  844286272.0
#  NN loss: 905.5988159179688, Physics loss: 0.0
# Epoch: 3000/10000, Loss: 1809.216552734375
# At iteration:  2999
#  The current value of Vx is:  -371267904.0
# At iteration:  2999
#  The current value of Vy is:  844286272.0
#  NN loss: 904.6082763671875, Physics loss: 0.0
# Epoch: 3100/10000, Loss: 1807.29345703125
# At iteration:  3099
#  The current value of Vx is:  -371267904.0
# At iteration:  3099
#  The current value of Vy is:  844286272.0
#  NN loss: 903.646728515625, Physics loss: 0.0
# Epoch: 3200/10000, Loss: 1805.425537109375
# At iteration:  3199
#  The current value of Vx is:  -371267904.0
# At iteration:  3199
#  The current value of Vy is:  844286272.0
#  NN loss: 902.7127685546875, Physics loss: 0.0
# Epoch: 3300/10000, Loss: 1803.6097412109375
# At iteration:  3299
#  The current value of Vx is:  -371267904.0
# At iteration:  3299
#  The current value of Vy is:  844286272.0
#  NN loss: 901.8048706054688, Physics loss: 0.0
# Epoch: 3400/10000, Loss: 1801.70458984375
# At iteration:  3399
#  The current value of Vx is:  -371267904.0
# At iteration:  3399
#  The current value of Vy is:  844286272.0
#  NN loss: 900.852294921875, Physics loss: 0.0
# Epoch: 3500/10000, Loss: 1799.9881591796875
# At iteration:  3499
#  The current value of Vx is:  -371267904.0
# At iteration:  3499
#  The current value of Vy is:  844286272.0
#  NN loss: 899.9940795898438, Physics loss: 0.0
# Epoch: 3600/10000, Loss: 1798.317626953125
# At iteration:  3599
#  The current value of Vx is:  -371267904.0
# At iteration:  3599
#  The current value of Vy is:  844286272.0
#  NN loss: 899.1588134765625, Physics loss: 0.0
# Epoch: 3700/10000, Loss: 1796.6309814453125
# At iteration:  3699
#  The current value of Vx is:  -371267904.0
# At iteration:  3699
#  The current value of Vy is:  844286272.0
#  NN loss: 898.3154907226562, Physics loss: 0.0
# Epoch: 3800/10000, Loss: 1795.0499267578125
# At iteration:  3799
#  The current value of Vx is:  -371267904.0
# At iteration:  3799
#  The current value of Vy is:  844286272.0
#  NN loss: 897.5249633789062, Physics loss: 0.0
# Epoch: 3900/10000, Loss: 1793.5098876953125
# At iteration:  3899
#  The current value of Vx is:  -371267904.0
# At iteration:  3899
#  The current value of Vy is:  844286272.0
#  NN loss: 896.7549438476562, Physics loss: 0.0
# Epoch: 4000/10000, Loss: 1792.0103759765625
# At iteration:  3999
#  The current value of Vx is:  -371267904.0
# At iteration:  3999
#  The current value of Vy is:  844286272.0
#  NN loss: 896.0051879882812, Physics loss: 0.0
# Epoch: 4100/10000, Loss: 1790.5487060546875
# At iteration:  4099
#  The current value of Vx is:  -371267904.0
# At iteration:  4099
#  The current value of Vy is:  844286272.0
#  NN loss: 895.2743530273438, Physics loss: 0.0
# Epoch: 4200/10000, Loss: 1789.126953125
# At iteration:  4199
#  The current value of Vx is:  -371267904.0
# At iteration:  4199
#  The current value of Vy is:  844286272.0
#  NN loss: 894.5634765625, Physics loss: 0.0
# Epoch: 4300/10000, Loss: 1787.671875
# At iteration:  4299
#  The current value of Vx is:  -371267904.0
# At iteration:  4299
#  The current value of Vy is:  844286272.0
#  NN loss: 893.8359375, Physics loss: 0.0
# Epoch: 4400/10000, Loss: 1786.324462890625
# At iteration:  4399
#  The current value of Vx is:  -371267904.0
# At iteration:  4399
#  The current value of Vy is:  844286272.0
#  NN loss: 893.1622314453125, Physics loss: 0.0
# Epoch: 4500/10000, Loss: 1785.0128173828125
# At iteration:  4499
#  The current value of Vx is:  -371267904.0
# At iteration:  4499
#  The current value of Vy is:  844286272.0
#  NN loss: 892.5064086914062, Physics loss: 0.0
# Epoch: 4600/10000, Loss: 1783.734375
# At iteration:  4599
#  The current value of Vx is:  -371267904.0
# At iteration:  4599
#  The current value of Vy is:  844286272.0
#  NN loss: 891.8671875, Physics loss: 0.0
# Epoch: 4700/10000, Loss: 1782.4912109375
# At iteration:  4699
#  The current value of Vx is:  -371267904.0
# At iteration:  4699
#  The current value of Vy is:  844286272.0
#  NN loss: 891.24560546875, Physics loss: 0.0
# Epoch: 4800/10000, Loss: 1781.28173828125
# At iteration:  4799
#  The current value of Vx is:  -371267904.0
# At iteration:  4799
#  The current value of Vy is:  844286272.0
#  NN loss: 890.640869140625, Physics loss: 0.0
# Epoch: 4900/10000, Loss: 1780.1053466796875
# At iteration:  4899
#  The current value of Vx is:  -371267904.0
# At iteration:  4899
#  The current value of Vy is:  844286272.0
#  NN loss: 890.0526733398438, Physics loss: 0.0
# Epoch: 5000/10000, Loss: 1778.9619140625
# At iteration:  4999
#  The current value of Vx is:  -371267904.0
# At iteration:  4999
#  The current value of Vy is:  844286272.0
#  NN loss: 889.48095703125, Physics loss: 0.0
# Epoch: 5100/10000, Loss: 1777.850341796875
# At iteration:  5099
#  The current value of Vx is:  -371267904.0
# At iteration:  5099
#  The current value of Vy is:  844286272.0
#  NN loss: 888.9251708984375, Physics loss: 0.0
# Epoch: 5200/10000, Loss: 1776.7705078125
# At iteration:  5199
#  The current value of Vx is:  -371267904.0
# At iteration:  5199
#  The current value of Vy is:  844286272.0
#  NN loss: 888.38525390625, Physics loss: 0.0
# Epoch: 5300/10000, Loss: 1775.7216796875
# At iteration:  5299
#  The current value of Vx is:  -371267904.0
# At iteration:  5299
#  The current value of Vy is:  844286272.0
#  NN loss: 887.86083984375, Physics loss: 0.0
# Epoch: 5400/10000, Loss: 1774.69140625
# At iteration:  5399
#  The current value of Vx is:  -371267904.0
# At iteration:  5399
#  The current value of Vy is:  844286272.0
#  NN loss: 887.345703125, Physics loss: 0.0
# Epoch: 5500/10000, Loss: 1773.7020263671875
# At iteration:  5499
#  The current value of Vx is:  -371267904.0
# At iteration:  5499
#  The current value of Vy is:  844286272.0
#  NN loss: 886.8510131835938, Physics loss: 0.0
# Epoch: 5600/10000, Loss: 1772.7427978515625
# At iteration:  5599
#  The current value of Vx is:  -371267904.0
# At iteration:  5599
#  The current value of Vy is:  844286272.0
#  NN loss: 886.3713989257812, Physics loss: 0.0
# Epoch: 5700/10000, Loss: 1771.8131103515625
# At iteration:  5699
#  The current value of Vx is:  -371267904.0
# At iteration:  5699
#  The current value of Vy is:  844286272.0
#  NN loss: 885.9065551757812, Physics loss: 0.0
# Epoch: 5800/10000, Loss: 1770.9124755859375
# At iteration:  5799
#  The current value of Vx is:  -371267904.0
# At iteration:  5799
#  The current value of Vy is:  844286272.0
#  NN loss: 885.4562377929688, Physics loss: 0.0
# Epoch: 5900/10000, Loss: 1770.040771484375
# At iteration:  5899
#  The current value of Vx is:  -371267904.0
# At iteration:  5899
#  The current value of Vy is:  844286272.0
#  NN loss: 885.0203857421875, Physics loss: 0.0
# Epoch: 6000/10000, Loss: 1769.2005615234375
# At iteration:  5999
#  The current value of Vx is:  -371267904.0
# At iteration:  5999
#  The current value of Vy is:  844286272.0
#  NN loss: 884.6002807617188, Physics loss: 0.0
# Epoch: 6100/10000, Loss: 1768.3836669921875
# At iteration:  6099
#  The current value of Vx is:  -371267904.0
# At iteration:  6099
#  The current value of Vy is:  844286272.0
#  NN loss: 884.1918334960938, Physics loss: 0.0
# Epoch: 6200/10000, Loss: 1767.518310546875
# At iteration:  6199
#  The current value of Vx is:  -371267904.0
# At iteration:  6199
#  The current value of Vy is:  844286272.0
#  NN loss: 883.7591552734375, Physics loss: 0.0
# Epoch: 6300/10000, Loss: 1766.7591552734375
# At iteration:  6299
#  The current value of Vx is:  -371267904.0
# At iteration:  6299
#  The current value of Vy is:  844286272.0
#  NN loss: 883.3795776367188, Physics loss: 0.0
# Epoch: 6400/10000, Loss: 1766.026611328125
# At iteration:  6399
#  The current value of Vx is:  -371267904.0
# At iteration:  6399
#  The current value of Vy is:  844286272.0
#  NN loss: 883.0133056640625, Physics loss: 0.0
# Epoch: 6500/10000, Loss: 1765.3201904296875
# At iteration:  6499
#  The current value of Vx is:  -371267904.0
# At iteration:  6499
#  The current value of Vy is:  844286272.0
#  NN loss: 882.6600952148438, Physics loss: 0.0
# Epoch: 6600/10000, Loss: 1764.639404296875
# At iteration:  6599
#  The current value of Vx is:  -371267904.0
# At iteration:  6599
#  The current value of Vy is:  844286272.0
#  NN loss: 882.3197021484375, Physics loss: 0.0
# Epoch: 6700/10000, Loss: 1763.98388671875
# At iteration:  6699
#  The current value of Vx is:  -371267904.0
# At iteration:  6699
#  The current value of Vy is:  844286272.0
#  NN loss: 881.991943359375, Physics loss: 0.0
# Epoch: 6800/10000, Loss: 1763.35400390625
# At iteration:  6799
#  The current value of Vx is:  -371267904.0
# At iteration:  6799
#  The current value of Vy is:  844286272.0
#  NN loss: 881.677001953125, Physics loss: 0.0
# Epoch: 6900/10000, Loss: 1762.7496337890625
# At iteration:  6899
#  The current value of Vx is:  -371267904.0
# At iteration:  6899
#  The current value of Vy is:  844286272.0
#  NN loss: 881.3748168945312, Physics loss: 0.0
# Epoch: 7000/10000, Loss: 1762.1688232421875
# At iteration:  6999
#  The current value of Vx is:  -371267904.0
# At iteration:  6999
#  The current value of Vy is:  844286272.0
#  NN loss: 881.0844116210938, Physics loss: 0.0
# Epoch: 7100/10000, Loss: 1761.612548828125
# At iteration:  7099
#  The current value of Vx is:  -371267904.0
# At iteration:  7099
#  The current value of Vy is:  844286272.0
#  NN loss: 880.8062744140625, Physics loss: 0.0
# Epoch: 7200/10000, Loss: 1761.0799560546875
# At iteration:  7199
#  The current value of Vx is:  -371267904.0
# At iteration:  7199
#  The current value of Vy is:  844286272.0
#  NN loss: 880.5399780273438, Physics loss: 0.0
# Epoch: 7300/10000, Loss: 1760.5709228515625
# At iteration:  7299
#  The current value of Vx is:  -371267904.0
# At iteration:  7299
#  The current value of Vy is:  844286272.0
#  NN loss: 880.2854614257812, Physics loss: 0.0
# Epoch: 7400/10000, Loss: 1760.08447265625
# At iteration:  7399
#  The current value of Vx is:  -371267904.0
# At iteration:  7399
#  The current value of Vy is:  844286272.0
#  NN loss: 880.042236328125, Physics loss: 0.0
# Epoch: 7500/10000, Loss: 1759.6204833984375
# At iteration:  7499
#  The current value of Vx is:  -371267904.0
# At iteration:  7499
#  The current value of Vy is:  844286272.0
#  NN loss: 879.8102416992188, Physics loss: 0.0
# Epoch: 7600/10000, Loss: 1759.17822265625
# At iteration:  7599
#  The current value of Vx is:  -371267904.0
# At iteration:  7599
#  The current value of Vy is:  844286272.0
#  NN loss: 879.589111328125, Physics loss: 0.0
# Epoch: 7700/10000, Loss: 1758.757568359375
# At iteration:  7699
#  The current value of Vx is:  -371267904.0
# At iteration:  7699
#  The current value of Vy is:  844286272.0
#  NN loss: 879.3787841796875, Physics loss: 0.0
# Epoch: 7800/10000, Loss: 1758.3577880859375
# At iteration:  7799
#  The current value of Vx is:  -371267904.0
# At iteration:  7799
#  The current value of Vy is:  844286272.0
#  NN loss: 879.1788940429688, Physics loss: 0.0
# Epoch: 7900/10000, Loss: 1757.978515625
# At iteration:  7899
#  The current value of Vx is:  -371267904.0
# At iteration:  7899
#  The current value of Vy is:  844286272.0
#  NN loss: 878.9892578125, Physics loss: 0.0
# Epoch: 8000/10000, Loss: 1757.6185302734375
# At iteration:  7999
#  The current value of Vx is:  -371267904.0
# At iteration:  7999
#  The current value of Vy is:  844286272.0
#  NN loss: 878.8092651367188, Physics loss: 0.0
# Epoch: 8100/10000, Loss: 1757.278076171875
# At iteration:  8099
#  The current value of Vx is:  -371267904.0
# At iteration:  8099
#  The current value of Vy is:  844286272.0
#  NN loss: 878.6390380859375, Physics loss: 0.0
# Epoch: 8200/10000, Loss: 1756.9564208984375
# At iteration:  8199
#  The current value of Vx is:  -371267904.0
# At iteration:  8199
#  The current value of Vy is:  844286272.0
#  NN loss: 878.4782104492188, Physics loss: 0.0
# Epoch: 8300/10000, Loss: 1756.6534423828125
# At iteration:  8299
#  The current value of Vx is:  -371267904.0
# At iteration:  8299
#  The current value of Vy is:  844286272.0
#  NN loss: 878.3267211914062, Physics loss: 0.0
# Epoch: 8400/10000, Loss: 1756.368408203125
# At iteration:  8399
#  The current value of Vx is:  -371267904.0
# At iteration:  8399
#  The current value of Vy is:  844286272.0
#  NN loss: 878.1842041015625, Physics loss: 0.0
# Epoch: 8500/10000, Loss: 1756.1002197265625
# At iteration:  8499
#  The current value of Vx is:  -371267904.0
# At iteration:  8499
#  The current value of Vy is:  844286272.0
#  NN loss: 878.0501098632812, Physics loss: 0.0
# Epoch: 8600/10000, Loss: 1755.84912109375
# At iteration:  8599
#  The current value of Vx is:  -371267904.0
# At iteration:  8599
#  The current value of Vy is:  844286272.0
#  NN loss: 877.924560546875, Physics loss: 0.0
# Epoch: 8700/10000, Loss: 1755.6138916015625
# At iteration:  8699
#  The current value of Vx is:  -371267904.0
# At iteration:  8699
#  The current value of Vy is:  844286272.0
#  NN loss: 877.8069458007812, Physics loss: 0.0
# Epoch: 8800/10000, Loss: 1755.394287109375
# At iteration:  8799
#  The current value of Vx is:  -371267904.0
# At iteration:  8799
#  The current value of Vy is:  844286272.0
#  NN loss: 877.6971435546875, Physics loss: 0.0
# Epoch: 8900/10000, Loss: 1755.189697265625
# At iteration:  8899
#  The current value of Vx is:  -371267904.0
# At iteration:  8899
#  The current value of Vy is:  844286272.0
#  NN loss: 877.5948486328125, Physics loss: 0.0
# Epoch: 9000/10000, Loss: 1754.9991455078125
# At iteration:  8999
#  The current value of Vx is:  -371267904.0
# At iteration:  8999
#  The current value of Vy is:  844286272.0
#  NN loss: 877.4995727539062, Physics loss: 0.0
# Epoch: 9100/10000, Loss: 1754.822509765625
# At iteration:  9099
#  The current value of Vx is:  -371267904.0
# At iteration:  9099
#  The current value of Vy is:  844286272.0
#  NN loss: 877.4112548828125, Physics loss: 0.0
# Epoch: 9200/10000, Loss: 1754.658935546875
# At iteration:  9199
#  The current value of Vx is:  -371267904.0
# At iteration:  9199
#  The current value of Vy is:  844286272.0
#  NN loss: 877.3294677734375, Physics loss: 0.0
# Epoch: 9300/10000, Loss: 1754.507568359375
# At iteration:  9299
#  The current value of Vx is:  -371267904.0
# At iteration:  9299
#  The current value of Vy is:  844286272.0
#  NN loss: 877.2537841796875, Physics loss: 0.0
# Epoch: 9400/10000, Loss: 1754.0428466796875
# At iteration:  9399
#  The current value of Vx is:  -371267904.0
# At iteration:  9399
#  The current value of Vy is:  844286272.0
#  NN loss: 877.0214233398438, Physics loss: 0.0
# Epoch: 9500/10000, Loss: 1753.2847900390625
# At iteration:  9499
#  The current value of Vx is:  -371267904.0
# At iteration:  9499
#  The current value of Vy is:  844286272.0
#  NN loss: 876.6423950195312, Physics loss: 0.0
# Epoch: 9600/10000, Loss: 1752.9820556640625
# At iteration:  9599
#  The current value of Vx is:  -371267904.0
# At iteration:  9599
#  The current value of Vy is:  844286272.0
#  NN loss: 876.4910278320312, Physics loss: 0.0
# Epoch: 9700/10000, Loss: 1751.0745849609375
# At iteration:  9699
#  The current value of Vx is:  -371267904.0
# At iteration:  9699
#  The current value of Vy is:  844286272.0
#  NN loss: 875.5372924804688, Physics loss: 0.0
# Epoch: 9800/10000, Loss: 1750.8572998046875
# At iteration:  9799
#  The current value of Vx is:  -371267904.0
# At iteration:  9799
#  The current value of Vy is:  844286272.0
#  NN loss: 875.4286499023438, Physics loss: 0.0
# Epoch: 9900/10000, Loss: 1750.817626953125
# At iteration:  9899
#  The current value of Vx is:  -371267904.0
# At iteration:  9899
#  The current value of Vy is:  844286272.0
#  NN loss: 875.4088134765625, Physics loss: 0.0
# Epoch: 10000/10000, Loss: 1750.7283935546875
# At iteration:  9999
#  The current value of Vx is:  -371267904.0
# At iteration:  9999
#  The current value of Vy is:  844286272.0
#  NN loss: 875.3641967773438, Physics loss: 0.0

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import torch
import imageio

def create_gif(frames, output_path, duration=0.1):
    imageio.mimsave(output_path, frames, duration=duration)

def animate2(x1, x2, i_plt, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    vmax = np.max(np.append(x1, x2))
    vmin = np.min(np.append(x1, x2))
    
    frames = min(x1.shape[2], x2.shape[2])  # Get the minimum number of frames
    
    # Initialize lists to store MAE and RMSE for each frame
    mae_list = []
    rmse_list = []
    
    # Initialize lists to store the frames for creating GIFs
    pred_frames = []
    true_frames = []
    
    for i in range(frames):
        fig, ax = plt.subplots(1, 3, figsize=(18, 5))  # Adjust the figure size as needed
        
        im1 = ax[0].imshow(x1[:, :, i], vmin=vmin, vmax=vmax)
        im2 = ax[1].imshow(x2[:, :, i], vmin=vmin, vmax=vmax)
        
        diff = x1[:, :, i] - x2[:, :, i]
        vmin_diff, vmax_diff = np.min(diff), np.max(diff)
        norm = mcolors.Normalize(vmin=vmin_diff, vmax=vmax_diff)
        im3 = ax[2].imshow(diff, cmap='viridis', norm=norm)
        
        fig.subplots_adjust(right=0.8)
        cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
        fig.colorbar(im3, cax=cbar_ax)
        
        # Add labels
        ax[0].set_title('Predicted')
        ax[1].set_title('True')
        ax[2].set_title('Difference')
        
        # Remove axis ticks
        for a in ax:
            a.set_xticks([])
            a.set_yticks([])
        
        # Calculate MAE and RMSE for the current frame
        mae = np.mean(np.abs(diff))
        rmse = np.sqrt(np.mean(diff ** 2))
        
        # Append MAE and RMSE to the lists
        mae_list.append(mae)
        rmse_list.append(rmse)
        
        # Add MAE and RMSE to the plot title
        fig.suptitle(f'Physics informed NN | i = {i_plt} Predict Frame - MAE: {mae:.4f}, RMSE: {rmse:.4f}', fontsize=12)
        
        # Save the current frame as an image file
        filename = f'FCNPiNNframe_{i_plt:04d}_{i+1:04d}.png'
        filepath = os.path.join(output_folder, filename)
        plt.savefig(filepath, bbox_inches='tight', pad_inches=0.1)
        plt.close(fig)
        
        # Append the current frame to the respective lists for creating GIFs
        pred_frames.append(x1[:, :, i])
        true_frames.append(x2[:, :, i])
    
    # Create and save the GIFs
    pred_gif_path = os.path.join(output_folder, f'pred_{i_plt:04d}.gif')
    true_gif_path = os.path.join(output_folder, f'true_{i_plt:04d}.gif')
    create_gif(pred_frames, pred_gif_path)
    create_gif(true_frames, true_gif_path)

# Testing loop
test_loss = 0.0
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
criterion = nn.MSELoss()

with torch.no_grad():
    for i_plt, (batch_x, batch_y) in enumerate(test_loader):
        print(f'batch_x shape: {batch_x.shape}\nbatch_y shape: {batch_y.shape}')
        batch_x = batch_x.reshape(batch_x.size(0), -1)
        batch_y = batch_y.reshape(batch_y.size(0), -1)  # Reshape batch_x to match the input size of the model
        
        if batch_x.shape[1] != N_INPUT:
            break
        
        # Forward pass
        output = pinn(batch_x)
        print(f'output shape: {output.shape}')
        
        # Compute data loss
        data_loss = criterion(output, batch_y)
        
        # Combine losses
        loss = data_loss
        
        test_loss += loss.item() * batch_x.size(0)
        
        # Plot the results for the current batch
        for j in range(batch_x.size(0)):
            print(f'Batch {i_plt}, Sample {j}, batch_x.shape: {batch_x[j].shape}, batch_y.shape: {batch_y[j].shape}, output.shape: {output[j].shape}')
            true = np.concatenate((batch_x[j].cpu().numpy().reshape(40, 40, 4), batch_y[j].cpu().numpy().reshape(40, 40, 1)), axis=2)
            pred = np.concatenate((batch_x[j].cpu().numpy().reshape(40, 40, 4), output[j].cpu().numpy().reshape(40, 40, 1)), axis=2)
            anim = animate2(pred, true, i_plt * batch_x.size(0) + j, '/home/sushen/PhysNet-RadarNowcast/2d-advection/nn_plot')

# Calculate average test loss
avg_test_loss = test_loss / len(test_loader.dataset)
print(f'Average Test Loss: {avg_test_loss:.4f}')
# Out:
# batch_x shape: torch.Size([196, 40, 40, 4])
# batch_y shape: torch.Size([196, 40, 40, 1])
# output shape: torch.Size([196, 1600])
# Batch 0, Sample 0, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 1, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 2, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 3, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 4, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 5, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 6, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 7, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 8, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 9, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 10, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 11, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 12, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 13, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 14, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 15, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 16, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 17, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 18, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 19, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 20, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 21, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 22, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 23, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 24, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 25, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 26, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 27, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 28, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 29, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 30, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 31, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 32, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 33, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 34, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 35, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 36, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 37, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 38, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 39, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 40, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 41, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 42, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 43, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 44, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 45, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 46, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 47, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 48, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 49, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 50, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 51, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 52, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 53, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 54, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 55, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 56, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 57, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 58, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 59, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 60, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 61, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 62, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 63, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 64, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 65, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 66, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 67, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 68, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 69, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 70, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 71, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 72, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 73, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 74, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 75, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 76, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 77, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 78, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 79, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 80, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 81, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 82, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 83, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 84, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 85, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 86, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 87, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 88, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 89, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 90, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 91, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 92, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 93, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 94, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 95, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 96, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 97, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 98, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 99, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 100, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 101, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 102, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 103, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 104, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 105, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 106, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 107, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 108, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 109, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 110, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 111, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 112, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 113, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 114, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 115, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 116, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 117, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 118, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 119, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 120, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 121, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 122, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 123, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 124, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 125, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 126, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 127, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 128, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 129, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 130, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 131, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 132, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 133, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 134, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 135, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 136, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 137, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 138, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 139, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 140, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 141, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 142, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 143, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 144, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 145, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 146, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 147, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 148, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 149, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 150, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 151, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 152, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 153, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 154, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 155, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 156, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 157, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 158, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 159, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 160, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 161, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 162, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 163, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 164, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 165, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 166, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 167, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 168, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 169, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 170, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 171, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 172, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 173, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 174, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 175, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 176, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 177, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 178, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 179, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 180, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 181, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 182, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 183, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 184, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 185, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 186, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 187, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 188, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 189, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 190, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 191, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 192, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 193, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 194, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Batch 0, Sample 195, batch_x.shape: torch.Size([6400]), batch_y.shape: torch.Size([1600]), output.shape: torch.Size([1600])
# Average Test Loss: 969.4605
